# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import numpy as np

# %%
# !pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 16.0 MB/s eta 0:00:0000:0100:01
# ...
#   WARNING: The script f2py is installed in '/home/z2034747/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gempy 2.2.6 requires pyvistaqt, which is not installed.
# pymc3 3.8 requires arviz>=0.4.1, which is not installed.
# basemap 1.3.3 requires matplotlib<3.6,>=1.5; python_version >= "3.5", but you have matplotlib 3.7.1 which is incompatible.
# basemap 1.3.3 requires numpy<1.23,>=1.21; python_version >= "3.7", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
with open('som_model.pkl', 'rb') as f:
    loaded_som = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 with open('som_model.pkl', 'rb') as f:
# ----> 2     loaded_som = pickle.load(f)
#
# TypeError: __randomstate_ctor() takes from 0 to 1 positional arguments but 2 were given

# %%
with open('./som_model.pkl', 'rb') as file:
    loaded_som = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 with open('./som_model.pkl', 'rb') as file:
# ----> 2     loaded_som = pickle.load(file)
#
# TypeError: __randomstate_ctor() takes from 0 to 1 positional arguments but 2 were given
